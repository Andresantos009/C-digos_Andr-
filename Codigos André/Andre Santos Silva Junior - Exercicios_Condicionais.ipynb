# %% [markdown]
# ### 📝Lista de Exercícios: Condicionais IF/ELSE

# %% [markdown]
# Exercício 1 - Maioridade 🔞
#
# Crie um programa que pergunta a idade do usuário e diz se ele é maior ou menor de idade.

# %%
idade = int(input("Quantos anos você tem? "))
if idade >= 18:
    print('Maior de idade')
else:
    print("Menor de idade")

# Complete o código aqui
# Out:
# Menor de idade

# %% [markdown]
# Exercício 2 - Aprovação na Prova 🧠
#
# Faça um programa que pergunte a nota de um aluno (0 a 10) e diz se ele foi aprovado(nota >= 5) ou reprovado (nota <5).

# %%
nota = float(input("Informe a sua nota de (0 a 10)"))
if nota >= 5:
    print('Voce foi aprovado')
else:
    print("Voce foi reprovado")
# Complete o código aqui
# Out:
# Voce foi reprovado

# %% [markdown]
# Exercicio 3 - CNH 🚘🚙
#
#  1º - Peça ao usuário que digite a idade dele.
#
#  2º - Peça pra ele dizer se foi aprovado ou reprovado no curso de cnh.
#
#  3º - Use if e else para verificar se ele tem 18 anos ou mais e se foi aprovado.
#
#  4º - Se as condições do passo 3 estiverem certas, print("pode dirigir").
#
#  5º - Se não print("vai andar a pé")

# %%
idade = int(input("digite a sua idade"))
aprovado = input(" Voce foi aprovado no curso de cnh?")
if idade >= 18 and aprovado == "sim":
    print("pode dirigir")
else:
    print("vai andar a pé")







### Seu código aqui
# Out:
# pode dirigir

# %% [markdown]
# Exercício 4 - Calculadora de Desconto. 💵 🤑
#
# Uma loja dá 10% de desconto para compras acima de R$ 100,00. Faça um programa que:
#
# 1º - Pergunta o valor da compra.
#
# 2º - Calcula o valor final com desconto (se aplicável).
#
# 3º - Mostra o valor a pagar.

# %%
### Seu código aqui

compra = int(input("Qual foi o valor da compra?"))
if compra > 100:
    compra = compra * 0.10
    print(f"voce teve o desconto de 10% de desconto, e o valor final foi de {compra}")
else:
    print(f"voce ultrapasou o valor de limite de desconto de {compra}")
# Out:
# voce teve o desconto de 10% de desconto, e o valor final foi de 19.900000000000002

# %% [markdown]
# Exercício 5 - Classificação de Notas 🧑‍🎓
#
# Pergunte a nota de um aluno e dependendo da nota que ele informar, o classifique de acordo com as regras abaixo:
#
# Classifique a nota do aluno:
#
# - 9 até 10: "Excelente"
#
# - 7 até 8.9: "Bom"
#
# - 5 até 6.9: "Regular"
#
# - 0 até 4.9: "Reprovado"
#
# mostre para o aluno a classificação dele através de um print, exemplo print("Excelente").

# %%
nota = int(input("Informe a sua nota de (0 a 10)"))
if nota >= 9 and nota<=10:
    print('exelente')
elif nota >= 7 and nota<=8.9:
    print("Bom")
elif nota >= 5 and nota<=6.9:
    print("Regular")
elif nota >= 0 and nota<=4.9:
    print("Reprovado")
# Out:
# exelente
# Bom
# Regular
# Reprovado

# %% [markdown]
# Exercício 6 - Acesso ao Sistema 🔑
#
# Crie um login simples:
#
# - usuario_correto = "admin"
#
# - senha_correta = "1234"
#
# **Peça para o usuário digitar primeiro o login e depois a senha, caso login e senha estejam corretos programa deve mostrar "Acesso permitido" se não "Acesso negado"**

# %%
usuario_correto = "admin"
senha_correta = 1234
login = input("digite o seu usuario")
senha = int(input("digite a sua senha"))
if login == usuario_correto and senha == senha_correta:
    print(f"Acesso permitido,{login}")
else:
    print("Acesso negado")
# Out:
# Acesso permitido,admin

# %% [markdown]
# Exercício 7 - Maior Número 📉
#
# Peça 3 números e mostre qual é o maior deles.

# %%
num1 = input("digite um numero")
num2 = input("digite um numero")
num3 = input("digite um numero")
total = max(num1, num2 , num3)
print(f"o maior numero é {total}")
# Out:
# o maior numero é 36

# %% [markdown]
# Exercício 8 - Dia da Semana
# Peça um número de 1 a 7 e mostre o dia da semana correspondente: 📅
#
# - 1: Domingo
#
# - 2: Segunda
#
# - ... até 7: Sábado

# %%
dia = int(input("digite um numero de 1 a 7"))
if dia == 1:
    print("domingo")
elif dia == 2:
    print("segunda")
elif dia == 3:
    print("terça")
elif dia == 4:
    print("Quarta")
elif dia == 5:
    print("Quinta")
elif dia == 6:
    print("Sexta")
elif dia == 7:
    print("Sabado")
# Out:
# Quinta

# %% [markdown]
# Exercício 9 - Calculadora Simples 📏📐
#
# - Faça uma calculadora que:
#
# - Pede dois números
#
# - Pede a operação (+, -, *, /)
#
# - Dependendo da operação mostre o resultado.

# %%
numero_1 = int (input("digite um numero"))
numero_2 = int (input("digite um numero"))
operaçao = (input("Escola a operacao(+, -, *, /)"))
total = numero_1 and operaçao and numero_2
print(f"o resultado é{total}")
# Out:
# o resultado é8

# %% [markdown]
# Exercício 10 - Sistema de Multas 🚙🚘🧾
#
#
# - Velocidade máxima: 80 km/h 🚫
#
# - Até 80: "Sem multa"
#
# - 81-100: "Multa leve"
#
# - Acima de 100: "Multa grave"

# %%
velocidade = int(input("Velocidade de locomoção"))
if velocidade == 80:
    print("Sem multa")
elif velocidade >= 81 and velocidade <=99:
    print("Multa leve")
elif velocidade>= 100:
    print("Multa grave")


# if velocidade >= 80:
#     print('Sem multa')
# elif velocidade >= 81 and velocidade <=100:
#     print("Mulçta leve")
# elif velocidade >= 100 :
#     print("MUlta grave")
# Out:
# Sem multa
